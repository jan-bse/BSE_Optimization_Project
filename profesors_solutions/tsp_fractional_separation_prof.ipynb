# %%
from gurobipy import Model, GRB, GurobiError
from graph_tool.generation import complete_graph
from graph_tool.flow import boykov_kolmogorov_max_flow, min_st_cut
import numpy as np

# %%
n = 50
V = range(n)
xs = np.random.uniform(low=0, high=100, size=n)
ys = np.random.uniform(low=0, high=100, size=n)
cost = {
    (i, j): (xs[i] - xs[j]) ** 2 + (ys[i] - ys[j]) ** 2
    for i in V for j in V if i != j
}
A = list(cost.keys())

# %%
G = complete_graph(N=n, self_loops=False, directed=True)
cap = G.new_edge_property(value_type='double')
G.edge_properties['cap'] = cap

# %%
m = Model()
x = m.addVars(A, vtype=GRB.BINARY, obj=cost, name='x')
m.addConstrs(x.sum(i, '*') == 1 for i in V)
m.addConstrs(x.sum('*', i) == 1 for i in V)
m.setParam(GRB.Param.LazyConstraints, 1)
# Out:
# Set parameter LazyConstraints to value 1

# %%
def set_capacity():
    for e in G.edges():
        i, j = e.source(), e.target()

        try:
            xval = m.cbGetSolution(x[i,j])
        except GurobiError:
            xval = m.cbGetNodeRel(x[i,j])

        cap[e] = xval

# %%
def add_sec_for(subtour):
    m.cbLazy(sum(x[i,j] for i,j in A if i in subtour and j not in subtour) >= 1)

# %%
def callback(what, where):
    if where not in (GRB.Callback.MIPSOL, GRB.Callback.MIPNODE):
        return
    
    if where == GRB.Callback.MIPNODE and m.cbGet(GRB.Callback.MIPNODE_STATUS) != GRB.OPTIMAL:
        return
    
    set_capacity()

    source = G.vertex(0)
    added  = set()

    for i in range(1, n):
        if i in added:
            continue

        sink = G.vertex(i)
        res = boykov_kolmogorov_max_flow(g=G, source=source, target=sink, capacity=cap)

        # Create an edge property map quickly by
        # copying an existing one.
        flow = res.copy()

        # The value held by the property map is in
        # the .a member. Because capacity == flow + residuals
        # we must write:
        flow.a = cap.a - res.a

        maxflow = sum(flow[a] for a in sink.in_edges())

        if maxflow < 1 - 1e-6:
            print(f"Violated SEC. Flow = {maxflow:.3f} < 1")
            cut = min_st_cut(g=G, source=source, capacity=cap, residual=res)

            assert cut[source] == True
            assert cut[sink] == False

            subtour = [j for j in V if cut[G.vertex(j)] == False]

            assert len(subtour) < n

            add_sec_for(subtour)

            added = added.union(subtour)

# %%
m.optimize(callback=callback)
# Out:
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (linux64 - "Fedora Linux 39 (KDE Plasma)")
#
# CPU model: Intel(R) Core(TM) i7-8550U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 100 rows, 2450 columns and 4900 nonzeros
# Model fingerprint: 0x7f9fdd5e
# Variable types: 0 continuous, 2450 integer (2450 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [6e+00, 1e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 148005.03092
# Presolve time: 0.02s
# Presolved: 100 rows, 2450 columns, 4900 nonzeros
# Variable types: 0 continuous, 2450 integer (2450 binary)
#
# Root relaxation: objective 5.375171e+03, 82 iterations, 0.00 seconds (0.00 work units)
# Violated SEC. Flow = 0.000 < 1
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 5375.17116    0    - 148005.031 5375.17116  96.4%     -    0s
# Violated SEC. Flow = 0.000 < 1
#      0     0 5419.05948    0    - 148005.031 5419.05948  96.3%     -    0s
# Violated SEC. Flow = 0.000 < 1
#      0     0 5446.97591    0    - 148005.031 5446.97591  96.3%     -    0s
#      0     0 5478.85706    0   20 148005.031 5478.85706  96.3%     -    0s
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
#      0     0 5558.33412    0   24 148005.031 5558.33412  96.2%     -    0s
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
#      0     2 5684.30085    0   28 148005.031 5684.30085  96.2%     -    0s
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.250 < 1
# Violated SEC. Flow = 0.250 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.750 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.333 < 1
# Violated SEC. Flow = 0.667 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = -0.000 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = -0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = -0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = -0.000 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.250 < 1
# Violated SEC. Flow = 0.750 < 1
# Violated SEC. Flow = 0.250 < 1
# Violated SEC. Flow = 0.750 < 1
# Violated SEC. Flow = 0.750 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.250 < 1
# Violated SEC. Flow = 0.750 < 1
# Violated SEC. Flow = 0.250 < 1
# Violated SEC. Flow = 0.750 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.250 < 1
# Violated SEC. Flow = 0.250 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.250 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.750 < 1
# Violated SEC. Flow = 0.750 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.200 < 1
# Violated SEC. Flow = 0.200 < 1
# Violated SEC. Flow = 0.800 < 1
# Violated SEC. Flow = 0.200 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.250 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.250 < 1
# Violated SEC. Flow = 0.750 < 1
# Violated SEC. Flow = 0.750 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.333 < 1
# Violated SEC. Flow = 0.333 < 1
# Violated SEC. Flow = 0.333 < 1
# Violated SEC. Flow = 0.444 < 1
# Violated SEC. Flow = 0.667 < 1
# Violated SEC. Flow = 0.667 < 1
# Violated SEC. Flow = 0.444 < 1
# Violated SEC. Flow = 0.889 < 1
# Violated SEC. Flow = 0.889 < 1
# Violated SEC. Flow = 0.333 < 1
# Violated SEC. Flow = 0.333 < 1
# Violated SEC. Flow = 0.333 < 1
# Violated SEC. Flow = 0.444 < 1
# Violated SEC. Flow = 0.667 < 1
# Violated SEC. Flow = 0.667 < 1
# Violated SEC. Flow = 0.444 < 1
# Violated SEC. Flow = 0.889 < 1
# Violated SEC. Flow = 0.889 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.313 < 1
# Violated SEC. Flow = 0.312 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.125 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.688 < 1
# Violated SEC. Flow = 0.063 < 1
# Violated SEC. Flow = 0.375 < 1
# Violated SEC. Flow = 0.625 < 1
# Violated SEC. Flow = 0.316 < 1
# Violated SEC. Flow = 0.316 < 1
# Violated SEC. Flow = 0.474 < 1
# Violated SEC. Flow = 0.105 < 1
# Violated SEC. Flow = 0.526 < 1
# Violated SEC. Flow = 0.684 < 1
# Violated SEC. Flow = 0.105 < 1
# Violated SEC. Flow = 0.368 < 1
# Violated SEC. Flow = 0.632 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.250 < 1
# Violated SEC. Flow = 0.250 < 1
# Violated SEC. Flow = 0.750 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.750 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.333 < 1
# Violated SEC. Flow = 0.333 < 1
# Violated SEC. Flow = 0.333 < 1
# Violated SEC. Flow = 0.333 < 1
# Violated SEC. Flow = 0.667 < 1
# Violated SEC. Flow = 0.667 < 1
# Violated SEC. Flow = 0.333 < 1
# Violated SEC. Flow = 0.667 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.333 < 1
# Violated SEC. Flow = 0.333 < 1
# Violated SEC. Flow = 0.333 < 1
# Violated SEC. Flow = 0.333 < 1
# Violated SEC. Flow = 0.333 < 1
# Violated SEC. Flow = 0.667 < 1
# Violated SEC. Flow = 0.333 < 1
# Violated SEC. Flow = 0.333 < 1
# Violated SEC. Flow = 0.333 < 1
# Violated SEC. Flow = 0.333 < 1
# Violated SEC. Flow = 0.333 < 1
# Violated SEC. Flow = 0.667 < 1
# Violated SEC. Flow = 0.667 < 1
# Violated SEC. Flow = 0.143 < 1
# Violated SEC. Flow = 0.286 < 1
# Violated SEC. Flow = 0.143 < 1
# Violated SEC. Flow = 0.857 < 1
# Violated SEC. Flow = 0.429 < 1
# Violated SEC. Flow = 0.571 < 1
# Violated SEC. Flow = 0.857 < 1
# Violated SEC. Flow = 0.429 < 1
# Violated SEC. Flow = 0.857 < 1
# Violated SEC. Flow = 0.857 < 1
# Violated SEC. Flow = 0.071 < 1
# Violated SEC. Flow = 0.571 < 1
# Violated SEC. Flow = 0.071 < 1
# Violated SEC. Flow = 0.929 < 1
# Violated SEC. Flow = 0.786 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.714 < 1
# Violated SEC. Flow = 0.929 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.333 < 1
# Violated SEC. Flow = 0.333 < 1
# Violated SEC. Flow = 0.667 < 1
# Violated SEC. Flow = 0.667 < 1
# Violated SEC. Flow = 0.667 < 1
# Violated SEC. Flow = 0.333 < 1
# Violated SEC. Flow = 0.333 < 1
# Violated SEC. Flow = 0.333 < 1
# Violated SEC. Flow = 0.333 < 1
# Violated SEC. Flow = 0.667 < 1
# Violated SEC. Flow = 0.333 < 1
# Violated SEC. Flow = 0.667 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = -0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.667 < 1
# Violated SEC. Flow = 0.333 < 1
# Violated SEC. Flow = 0.333 < 1
# Violated SEC. Flow = 0.333 < 1
# Violated SEC. Flow = 0.667 < 1
# Violated SEC. Flow = 0.667 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.000 < 1
#     64    43 7389.15047   10   62 148005.031 6074.95169  95.9%  21.9    5s
# Violated SEC. Flow = -0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.667 < 1
# Violated SEC. Flow = 0.333 < 1
# Violated SEC. Flow = 0.333 < 1
# Violated SEC. Flow = 0.667 < 1
# Violated SEC. Flow = 0.333 < 1
# Violated SEC. Flow = 0.333 < 1
# Violated SEC. Flow = 0.667 < 1
# Violated SEC. Flow = 0.667 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.250 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.250 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.750 < 1
# Violated SEC. Flow = 0.750 < 1
# Violated SEC. Flow = 0.667 < 1
# Violated SEC. Flow = 0.667 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.667 < 1
# Violated SEC. Flow = 0.333 < 1
# Violated SEC. Flow = 0.667 < 1
# Violated SEC. Flow = 0.667 < 1
# Violated SEC. Flow = 0.667 < 1
# Violated SEC. Flow = 0.667 < 1
# Violated SEC. Flow = 0.333 < 1
# Violated SEC. Flow = 0.667 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.750 < 1
# Violated SEC. Flow = 0.750 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.750 < 1
# Violated SEC. Flow = 0.750 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.750 < 1
# Violated SEC. Flow = 0.250 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.750 < 1
# Violated SEC. Flow = 0.750 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.750 < 1
# Violated SEC. Flow = 0.250 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.750 < 1
# Violated SEC. Flow = 0.750 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.375 < 1
# Violated SEC. Flow = 0.250 < 1
# Violated SEC. Flow = 0.750 < 1
# Violated SEC. Flow = 0.250 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.375 < 1
# Violated SEC. Flow = 0.750 < 1
# Violated SEC. Flow = 0.800 < 1
# Violated SEC. Flow = 0.600 < 1
# Violated SEC. Flow = 0.400 < 1
# Violated SEC. Flow = 0.800 < 1
# Violated SEC. Flow = 0.200 < 1
# Violated SEC. Flow = 0.600 < 1
# Violated SEC. Flow = 0.400 < 1
# Violated SEC. Flow = 0.800 < 1
# Violated SEC. Flow = 0.800 < 1
# Violated SEC. Flow = 0.600 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.833 < 1
# Violated SEC. Flow = 0.833 < 1
# Violated SEC. Flow = 0.833 < 1
# Violated SEC. Flow = 0.833 < 1
# Violated SEC. Flow = 0.833 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.833 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = -0.000 < 1
# Violated SEC. Flow = -0.000 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = -0.000 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.750 < 1
#    144    77 8982.12978   13   56 148005.031 6098.32630  95.9%  26.5   10s
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.667 < 1
# Violated SEC. Flow = 0.667 < 1
# Violated SEC. Flow = 0.667 < 1
# Violated SEC. Flow = 0.333 < 1
# Violated SEC. Flow = 0.667 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.667 < 1
# Violated SEC. Flow = 0.667 < 1
# Violated SEC. Flow = 0.667 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# *  175    96               5    8975.9398924 6098.32630  32.1%  24.5   12s
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# Violated SEC. Flow = 0.500 < 1
# *  185    81               5    8404.6876226 6104.60663  27.4%  23.7   12s
# *  186    81               5    8332.8828757 6104.60663  26.7%  24.0   12s
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
# Violated SEC. Flow = 0.000 < 1
#
# Cutting planes:
#   Lazy constraints: 549
#
# Explored 280 nodes (6190 simplex iterations) in 13.28 seconds (0.87 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 8332.88 8404.69 8975.94 148005
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.332882875685e+03, best bound 8.332882875685e+03, gap 0.0000%
#
# User-callback calls 944, time in user-callback 11.91 sec
