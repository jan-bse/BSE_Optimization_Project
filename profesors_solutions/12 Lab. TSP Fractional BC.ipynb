# %%
from typing import Dict, Tuple, List
from math import sqrt
from dataclasses import dataclass
from gurobipy import Model, GRB, tupledict, LinExpr, GurobiError
from itertools import combinations

from graph_tool import Graph, EdgePropertyMap
from graph_tool.generation import complete_graph
from graph_tool.flow import boykov_kolmogorov_max_flow, min_st_cut

import matplotlib.pyplot as plt
from matplotlib.figure import Figure

# %%
class TspInstance:
    """ An instance of the Travelling Salesman Problem.

        Attributes
        ----------
        n_vertices: int
            Number of vertices in the graph.
        x: List[float]
            X coordinates of the vertices (for plotting).
        y: List[float]
            Y coordinates of the vertices (for plotting).
        cost: Dict[Tuple[int, int], float]
            Dictionary with arcs as key, and their corresponding
            costs as values.
    """

    n_vertices: int
    x: List[float]
    y: List[float]
    cost: Dict[Tuple[int, int], float]

    def __euclidean_distance(self, i: int, j: int) -> float:
        assert 0 <= i < self.n_vertices
        assert 0 <= j < self.n_vertices
        return sqrt((self.x[i] - self.x[j]) ** 2 + (self.y[i] - self.y[j]) ** 2)

    def __init__(self, file: str):
        """ Reads a (Euclidean) TSP instance from file.

            The file must follow the following format. The first
            line must contain a single integer number, representing
            the number of vertices (n) in the graph. The next n
            lines must contain two floating point numbers separated
            by a space. These are the x and y coordinates of each
            vertex. The cost to travel from i to j will be computed
            as the euclidean distance between them.

            Parameters
            ----------
            file: str
                Path to the file containing the instance.
        """

        with open(file) as f:
            # First line
            self.n_vertices = int(f.readline().strip())

            # Subsequent n_vertices lines
            self.x, self.y = zip(*[map(float, f.readline().strip().split()) for _ in range(self.n_vertices)])

            # Create the cost dictionary from the x-y coordinates
            self.cost = {
                (i, j): self.__euclidean_distance(i, j)
                for i in range(self.n_vertices)
                for j in range(self.n_vertices)
                if i != j
            }

@dataclass
class TspSolution:
    """ Solution to an instance of the Travelling Salesman Problem.

        Attributes
        ----------
        instance: TspInstance
            Reference to the TSP instance being solved.
        tour: List[int]
            Ordered list of vertices visited (without repeating the first one).
        cost: float
            Travel cost of the tour.
    """

    instance: TspInstance
    tour: List[int]
    cost: float

    def plot(self) -> Tuple[Figure, plt.Axes]:
        """ Plots the solution of the TSP.
        
            Vertices are black dots, the solution is represented by red lines.

            Returns
            -------
            A tuple with the figure and axes object from matplotlib.    
        """

        xy = [(self.instance.x[i], self.instance.y[i]) for i in self.tour + [self.tour[0]]]

        fig, ax = plt.subplots(figsize=(10, 10))
        ax.scatter(self.instance.x, self.instance.y, color='black')
        
        for pt1, pt2 in zip(xy[1:], xy[:-1]):
            x1, y1 = pt1
            x2, y2 = pt2
            ax.plot([x1, x2], [y1, y2], color='red')

        ax.set_title(f"TSP Solution. Num vertices: {self.instance.n_vertices}. Tour cost: {self.cost:.2f}.")
        ax.set_axis_off()

        return fig, ax

class TspFractionalBCSolver:
    """ Solver for the Travelling Salesman Problem.
    
        It uses the branch-and-cut algorithm applied to the "DFJ" formulation.
        Subtour elimination constraints are separated on integer and
        fractional solutions alike.
    """

    _EPS: float = 1e-6

    _instance: TspInstance
    _V: List[int]
    _A: List[Tuple[int, int]]
    _g: Graph
    _cap: EdgePropertyMap
    _model: Model
    _x: tupledict

    def __init__(self, instance: TspInstance):
        """ Initialises the solver and builds the model.
        
            Parameters
            ----------
            instance: TspInstance
                The TSP instance.
        """

        self._instance = instance
        self._V = list(range(self._instance.n_vertices))
        self._A = list(self._instance.cost.keys())
        self.__build_graph()
        self.__build_model()

    def __build_graph(self) -> None:
        """ Builds the graph for cut separation. """
        self._g = complete_graph(N=self._instance.n_vertices, self_loops=False, directed=True)
        self._cap = self._g.new_edge_property(value_type='double')
        self._g.edge_properties['cap'] = self._cap       

    def __build_model(self) -> None:
        """ Builds the DFJ model without SECs. """
         
        self._model = Model()
        self._x = self._model.addVars(self._A, obj=self._instance.cost, vtype=GRB.BINARY, name='x')
        self._model.addConstrs((self._x.sum(i, '*') == 1 for i in self._V), name='outgoing')
        self._model.addConstrs((self._x.sum('*', i) == 1 for i in self._V), name='incoming')

    def __next_vertex(self, i: int) -> int:
        """ Gets the vertex visited immediately after i in the current TSP solution.

            This is the (only) vertex j such that x[i,j] == 1. This function works both
            when inside a callback (when the value of x must be retrieved via cbGetSolution)
            and after the optimisation is over (when the value of X can be accessed via X).
        """

        assert 0 <= i < self._instance.n_vertices

        for j in self._V:
            if i != j:
                try:
                    # If inside a call-back, we use cbGetSolution
                    val = self._model.cbGetSolution(self._x[i, j])
                except:
                    # Otherwise we use .X
                    val = self._x[i, j].X

                if val > 0.5:
                    return j

        assert False, f"Vertex {j} has no successor?!"

    def __tour_staring_at(self, i: int) -> List[int]:
        """ Gives the (sub)tour starting at a given vertex i in the current TSP solution. """

        assert 0 <= i < self._instance.n_vertices

        tour = [i]
        current = self.__next_vertex(i)

        while current != i:
            tour.append(current)
            current = self.__next_vertex(current)

        return tour

    def __add_sec_for(self, S: List[int]) -> None:
        """ Adds a Subtour Elimination Constraint for set S. """

        assert 0 < len(S) < self._instance.n_vertices

        self._model.cbLazy(sum(self._x[i, j] for (i, j) in self._A if i in S and j not in S) >= 1)

    def __set_capacity(self) -> None:
        """ Sets graph capacity based on current solution. """

        for e in self._g.edges():
            i, j = e.source(), e.target()

            try: # If we are in MIPSOL
                xval = self._model.cbGetSolution(self._x[i,j])
            except: # If we are in MIPNODE
                xval = self._model.cbGetNodeRel(self._x[i,j])

            self._cap[e] = xval

    def __separate(self, where: int) -> None:
        """ Separates eventual violated SECs. """

        if where not in [GRB.Callback.MIPSOL, GRB.Callback.MIPNODE]:
            return

        # In MIPNODE, we must ensure that we have the optimal solution to the
        # linear relaxation at that node. Otherwise we are not "authorised"
        # to call cbGetNodeRel. See:
        # https://www.gurobi.com/documentation/9.1/refman/py_model_cbgetnoderel.html
        if where == GRB.Callback.MIPNODE and self._model.cbGet(GRB.Callback.MIPNODE_STATUS) != GRB.OPTIMAL:
            return
        
        self.__set_capacity()

        source = self._g.vertex(0)
        already_added = set()

        print('Separation round!')

        for i in range(1, self._instance.n_vertices):
            if i in already_added:
                continue

            target = self._g.vertex(i)
            residual = boykov_kolmogorov_max_flow(
                g=self._g, source=source, target=target,
                capacity=self._cap
            )
            
            flow = residual.copy()
            flow.a = self._cap.a - residual.a

            total_flow = sum(flow[a] for a in target.in_edges())

            if total_flow < 1 - self._EPS: # Avoid numerical issues
                print(f"\tFound a subset which violate a SEC (flow = {total_flow:.3f} < 1)")
                
                cut = min_st_cut(g=self._g, source=source,capacity=self._cap, residual=residual)

                assert cut[source] == True
                assert cut[target] == False

                subtour = [j for j in self._V if cut[self._g.vertex(j)] == False]

                assert len(subtour) < self._instance.n_vertices

                print(f"\tSet size: {len(subtour)}")

                self.__add_sec_for(subtour)

                already_added = already_added.union(subtour)

    def solve(self) -> TspSolution:
        """ Solves the TSP DFJ model and returns the solution.
        
            It throws a RuntimeError if Gurobi cannot solve the model to optimality.

            Returns
            -------
            A TspSolution object with details about the solution.
        """

        # We must set this parameter to use callbacks
        self._model.setParam(GRB.Param.LazyConstraints, 1)

        # Gurobi always passes two parameters to the callback: `model` and `where`
        self._model.optimize(lambda _, where: self.__separate(where))

        if self._model.Status != GRB.OPTIMAL:
            raise RuntimeError(f"Could not find the optimal solution. Gurobi status = {self._model.Status}")

        return TspSolution(
            instance=self._instance,
            tour=self.__tour_staring_at(0),
            cost=self._model.ObjVal
        )

# %%
instance = TspInstance(file='../data/tsp-instance.txt')

# %%
solver = TspFractionalBCSolver(instance=instance)

# %%
solution = solver.solve()
# Out:
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Core(TM) i7-6600U CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 100 rows, 2450 columns and 4900 nonzeros
# Model fingerprint: 0xb06afe35
# Variable types: 0 continuous, 2450 integer (2450 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Separation round!
# Found heuristic solution: objective 2543.7515673
# Presolve time: 0.02s
# Presolved: 100 rows, 2450 columns, 4900 nonzeros
# Variable types: 0 continuous, 2450 integer (2450 binary)
#
# Root relaxation: objective 4.552846e+02, 81 iterations, 0.00 seconds (0.00 work units)
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 43
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  455.28464    0    - 2543.75157  455.28464  82.1%     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 48
#      0     0  459.15574    0    - 2543.75157  459.15574  81.9%     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 42
#      0     0  460.83662    0    - 2543.75157  460.83662  81.9%     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 40
#      0     0  461.13125    0    - 2543.75157  461.13125  81.9%     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 48
#      0     0  465.93611    0    - 2543.75157  465.93611  81.7%     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 44
#      0     0  466.88948    0    - 2543.75157  466.88948  81.6%     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 41
#      0     0  467.76288    0    - 2543.75157  467.76288  81.6%     -    0s
#      0     0  469.86940    0   29 2543.75157  469.86940  81.5%     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 42
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 44
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 47
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 42
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 38
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 38
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 37
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 40
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 39
#      0     0  469.97221    0    - 2543.75157  469.97221  81.5%     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 37
#      0     0  470.18361    0    - 2543.75157  470.18361  81.5%     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 38
#      0     0  471.26046    0    - 2543.75157  471.26046  81.5%     -    0s
#      0     0  471.59862    0   34 2543.75157  471.59862  81.5%     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 33
# 	Found a subset which violate a SEC (flow = 0.250 < 1)
# 	Set size: 33
# 	Found a subset which violate a SEC (flow = 0.750 < 1)
# 	Set size: 45
# 	Found a subset which violate a SEC (flow = 0.750 < 1)
# 	Set size: 36
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 42
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 39
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 40
# Separation round!
# H    0     0                    2115.1384342  471.59862  77.7%     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 34
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 42
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 40
#      0     2  475.48372    0   32 2115.13843  475.48372  77.5%     -    0s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 33
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 31
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 33
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 38
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 44
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 33
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 31
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 33
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 40
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 44
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 29
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 32
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 35
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 39
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 32
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 46
# Separation round!
# 	Found a subset which violate a SEC (flow = -0.000 < 1)
# 	Set size: 34
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 46
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 37
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 29
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 29
# 	Found a subset which violate a SEC (flow = 0.167 < 1)
# 	Set size: 27
# 	Found a subset which violate a SEC (flow = 0.167 < 1)
# 	Set size: 34
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 30
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 28
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 30
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 30
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 30
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 38
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 32
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 32
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 34
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 42
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 37
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 38
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 18
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 19
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 30
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 20
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 23
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 20
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.250 < 1)
# 	Set size: 28
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 30
# 	Found a subset which violate a SEC (flow = 0.250 < 1)
# 	Set size: 27
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 40
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 41
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.182 < 1)
# 	Set size: 19
# 	Found a subset which violate a SEC (flow = 0.091 < 1)
# 	Set size: 23
# 	Found a subset which violate a SEC (flow = 0.364 < 1)
# 	Set size: 30
# 	Found a subset which violate a SEC (flow = 0.364 < 1)
# 	Set size: 25
# 	Found a subset which violate a SEC (flow = 0.545 < 1)
# 	Set size: 26
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 30
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 32
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 32
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 37
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 34
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 35
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 40
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.400 < 1)
# 	Set size: 31
# 	Found a subset which violate a SEC (flow = 0.400 < 1)
# 	Set size: 21
# 	Found a subset which violate a SEC (flow = 0.600 < 1)
# 	Set size: 22
# 	Found a subset which violate a SEC (flow = 0.600 < 1)
# 	Set size: 23
# 	Found a subset which violate a SEC (flow = 0.400 < 1)
# 	Set size: 24
# 	Found a subset which violate a SEC (flow = 0.200 < 1)
# 	Set size: 15
# 	Found a subset which violate a SEC (flow = 0.400 < 1)
# 	Set size: 30
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.600 < 1)
# 	Set size: 23
# 	Found a subset which violate a SEC (flow = 0.200 < 1)
# 	Set size: 24
# 	Found a subset which violate a SEC (flow = 0.600 < 1)
# 	Set size: 28
# 	Found a subset which violate a SEC (flow = 0.800 < 1)
# 	Set size: 31
# 	Found a subset which violate a SEC (flow = 0.800 < 1)
# 	Set size: 32
# 	Found a subset which violate a SEC (flow = 0.800 < 1)
# 	Set size: 26
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 28
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 28
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 26
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 31
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 38
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 46
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 47
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 36
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 36
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 32
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 30
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 18
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 14
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 23
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 15
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 19
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 24
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 33
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 14
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 20
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 32
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 32
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 32
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 39
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 31
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 10
# 	Found a subset which violate a SEC (flow = 0.250 < 1)
# 	Set size: 21
# 	Found a subset which violate a SEC (flow = 0.250 < 1)
# 	Set size: 14
# 	Found a subset which violate a SEC (flow = 0.250 < 1)
# 	Set size: 9
# 	Found a subset which violate a SEC (flow = 0.750 < 1)
# 	Set size: 14
# 	Found a subset which violate a SEC (flow = 0.250 < 1)
# 	Set size: 9
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 31
# 	Found a subset which violate a SEC (flow = 0.750 < 1)
# 	Set size: 12
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 46
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 22
# 	Found a subset which violate a SEC (flow = 0.750 < 1)
# 	Set size: 42
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 26
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 32
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 16
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 8
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 16
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 16
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 15
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 23
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 18
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 32
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 31
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.125 < 1)
# 	Set size: 20
# 	Found a subset which violate a SEC (flow = 0.875 < 1)
# 	Set size: 24
# 	Found a subset which violate a SEC (flow = 0.875 < 1)
# 	Set size: 30
# 	Found a subset which violate a SEC (flow = 0.625 < 1)
# 	Set size: 17
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 20
# 	Found a subset which violate a SEC (flow = 0.875 < 1)
# 	Set size: 28
# 	Found a subset which violate a SEC (flow = 0.750 < 1)
# 	Set size: 21
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.364 < 1)
# 	Set size: 14
# 	Found a subset which violate a SEC (flow = 0.818 < 1)
# 	Set size: 18
# 	Found a subset which violate a SEC (flow = 0.909 < 1)
# 	Set size: 29
# 	Found a subset which violate a SEC (flow = 0.091 < 1)
# 	Set size: 12
# 	Found a subset which violate a SEC (flow = 0.273 < 1)
# 	Set size: 12
# 	Found a subset which violate a SEC (flow = 0.909 < 1)
# 	Set size: 28
# 	Found a subset which violate a SEC (flow = 0.909 < 1)
# 	Set size: 30
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 2
# 	Found a subset which violate a SEC (flow = 0.267 < 1)
# 	Set size: 9
# 	Found a subset which violate a SEC (flow = 0.467 < 1)
# 	Set size: 20
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 18
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 28
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 4
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 25
# 	Found a subset which violate a SEC (flow = 0.800 < 1)
# 	Set size: 33
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 24
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.296 < 1)
# 	Set size: 4
# 	Found a subset which violate a SEC (flow = 0.704 < 1)
# 	Set size: 21
# 	Found a subset which violate a SEC (flow = 0.852 < 1)
# 	Set size: 25
# 	Found a subset which violate a SEC (flow = 0.222 < 1)
# 	Set size: 11
# 	Found a subset which violate a SEC (flow = 0.852 < 1)
# 	Set size: 28
# 	Found a subset which violate a SEC (flow = 0.556 < 1)
# 	Set size: 9
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 25
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 28
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 25
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 24
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 16
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 15
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 13
# Separation round!
# 	Found a subset which violate a SEC (flow = -0.000 < 1)
# 	Set size: 10
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 21
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 12
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 12
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 20
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 24
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 18
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 16
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 27
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 15
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.750 < 1)
# 	Set size: 24
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 20
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 29
# 	Found a subset which violate a SEC (flow = 0.750 < 1)
# 	Set size: 26
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 22
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 22
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 18
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 23
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 24
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 19
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 16
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 22
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 16
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 17
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 21
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 19
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 22
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 19
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 18
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 15
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 9
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 8
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 7
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 15
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 14
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 20
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 14
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 16
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 16
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 17
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 14
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.400 < 1)
# 	Set size: 16
# 	Found a subset which violate a SEC (flow = 0.800 < 1)
# 	Set size: 30
# 	Found a subset which violate a SEC (flow = 0.800 < 1)
# 	Set size: 13
# 	Found a subset which violate a SEC (flow = 0.400 < 1)
# 	Set size: 14
# 	Found a subset which violate a SEC (flow = 0.800 < 1)
# 	Set size: 38
# 	Found a subset which violate a SEC (flow = 0.600 < 1)
# 	Set size: 14
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 2
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 2
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 4
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 9
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 2
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 2
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 3
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.400 < 1)
# 	Set size: 13
# 	Found a subset which violate a SEC (flow = 0.800 < 1)
# 	Set size: 30
# 	Found a subset which violate a SEC (flow = 0.800 < 1)
# 	Set size: 11
# 	Found a subset which violate a SEC (flow = 0.400 < 1)
# 	Set size: 14
# 	Found a subset which violate a SEC (flow = 0.800 < 1)
# 	Set size: 38
# 	Found a subset which violate a SEC (flow = 0.400 < 1)
# 	Set size: 14
# 	Found a subset which violate a SEC (flow = 0.800 < 1)
# 	Set size: 13
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 20
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 20
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 3
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 3
# 	Found a subset which violate a SEC (flow = -0.000 < 1)
# 	Set size: 2
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 5
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 4
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 14
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 6
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 28
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 27
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 22
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 37
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 12
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 13
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 13
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 10
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 37
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 28
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 21
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 15
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 14
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.714 < 1)
# 	Set size: 10
# 	Found a subset which violate a SEC (flow = 0.714 < 1)
# 	Set size: 11
# 	Found a subset which violate a SEC (flow = 0.714 < 1)
# 	Set size: 11
# 	Found a subset which violate a SEC (flow = 0.857 < 1)
# 	Set size: 9
# 	Found a subset which violate a SEC (flow = 0.714 < 1)
# 	Set size: 13
# 	Found a subset which violate a SEC (flow = 0.857 < 1)
# 	Set size: 9
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 10
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 11
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 11
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 9
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 13
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 8
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 21
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 16
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 19
# 	Found a subset which violate a SEC (flow = -0.000 < 1)
# 	Set size: 22
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 22
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 15
#     74    43  544.34730    5    - 2115.13843  482.29184  77.2%  32.9    5s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 8
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 13
# 	Found a subset which violate a SEC (flow = -0.000 < 1)
# 	Set size: 8
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 6
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 5
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 7
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 5
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 8
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 4
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 4
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 13
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 11
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 12
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 13
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 10
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 36
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 5
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 9
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 4
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 11
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 9
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 10
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 11
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 8
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 8
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 3
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 5
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 6
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 3
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 2
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 7
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 6
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 9
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 4
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 12
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 7
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 4
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 4
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 4
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 12
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 12
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 6
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 3
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 7
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 2
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 6
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 4
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 5
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 10
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 4
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 9
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 2
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 2
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 2
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 15
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 6
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 4
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 4
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 6
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 8
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 2
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.750 < 1)
# 	Set size: 2
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 5
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 4
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 4
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 4
# Separation round!
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 4
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 2
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 2
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 2
# Separation round!
# Separation round!
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 7
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 9
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 9
# Separation round!
# Separation round!
# Separation round!
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 2
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 5
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 7
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 7
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 4
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 7
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 4
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 5
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 7
# Separation round!
# Separation round!
# Separation round!
# *  119    70              16     577.3306111  482.29184  16.5%  27.5    7s
# Separation round!
# Separation round!
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 6
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 2
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 3
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 2
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 8
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.333 < 1)
# 	Set size: 2
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 2
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 3
# Separation round!
# Separation round!
# Separation round!
# Separation round!
# Separation round!
# *  132    70              18     577.3302058  486.25066  15.8%  25.9    7s
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 3
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 17
# Separation round!
# Separation round!
# Separation round!
# *  136    70               8     566.9913820  486.25066  14.2%  26.5    8s
# Separation round!
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 2
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 7
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 6
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 6
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.000 < 1)
# 	Set size: 6
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 6
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.750 < 1)
# 	Set size: 4
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.667 < 1)
# 	Set size: 4
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 4
# Separation round!
# 	Found a subset which violate a SEC (flow = 0.500 < 1)
# 	Set size: 4
# Separation round!
# Separation round!
# Separation round!
# Separation round!
# Separation round!
# *  156    69               5     562.2011490  486.25066  13.5%  25.3    8s
# Separation round!
# Separation round!
# *  160    66               7     561.2078035  495.55174  11.7%  27.3    8s
# Separation round!
# Separation round!
# Separation round!
# *  197     0               7     560.7578786  539.63821  3.77%  34.2    9s
# Separation round!
#
# Cutting planes:
#   Lazy constraints: 376
#
# Explored 227 nodes (7037 simplex iterations) in 9.20 seconds (1.41 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 8: 560.758 561.208 562.201 ... 2543.75
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.607578785774e+02, best bound 5.607578785774e+02, gap 0.0000%
#
# User-callback calls 893, time in user-callback 8.07 sec
